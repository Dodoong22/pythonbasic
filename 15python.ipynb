# %%
import pandas as pd
import seaborn as sns

titanic = sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.age.notnull()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Name: age, Length: 891, dtype: bool

# %%
titanic_n = titanic[titanic.age.notnull()]

# %%
titanic_n
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ### dropna()
# DataFrame 내에 있는 결측치를 제거함.

# %%
titanic = sns.load_dataset("titanic")
titanic.count()
# Out:
# survived       891
# pclass         891
# sex            891
# age            714
# sibsp          891
# parch          891
# fare           891
# embarked       889
# class          891
# who            891
# adult_male     891
# deck           203
# embark_town    889
# alive          891
# alone          891
# dtype: int64

# %%
titanic.dropna(subset=["age"], inplace=True)
titanic.count()
# Out:
# survived       714
# pclass         714
# sex            714
# age            714
# sibsp          714
# parch          714
# fare           714
# embarked       712
# class          714
# who            714
# adult_male     714
# deck           184
# embark_town    712
# alive          714
# alone          714
# dtype: int64

# %%
titanic["adult_female"] = (titanic["sex"] == "female") & (titanic["age"] >= 20)

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
import matplotlib.font_manager as font_manager
import matplotlib as mpl
import matplotlib.pyplot as plt
# Add every font at the specified location
font_dir = ['C:/python/fonts']
for font in font_manager.findSystemFonts(fontpaths=font_dir):
    print(mpl.font_manager.FontProperties(fname=font).get_name())
    font_manager.fontManager.addfont(font)
# Set font family globally
mpl.rcParams['font.family'] = 'NanumMyeongjo'
print(mpl.rcParams['font.family'])
# Out:
# NanumMyeongjo
# NanumMyeongjo
# NanumMyeongjo
# NanumMyeongjo
# ['NanumMyeongjo']

# %%
plt.title("한글")
plt.show()

# %%
mpl.rc('axes', unicode_minus = False)

# %% [markdown]
# tight_layout() 명령 실행시 플롯 간 간격을 자동을 맞춰줌

# %%
import numpy as np

x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

ax1 = plt.subplot(2,1,1)
plt.plot(x1, y1, 'yo-')
plt.title('A tale of 2 subplots')
plt.ylabel('Dampled oscillation')

ax2 = plt.subplot(2, 1, 2)
plt.plot(x2, y2, 'r.-')
plt.xlabel('time (s)')
plt.ylabel('Undampled')

plt.tight_layout()
plt.show()

# %%
import random
np.random.seed(0)

plt.subplot(221)
plt.plot(np.random.rand(5))
plt.title("axes 1")

plt.subplot(222)
plt.plot(np.random.rand(5))
plt.title("axes 2")

plt.subplot(223)
plt.plot(np.random.rand(5))
plt.title("axes 3")

plt.subplot(224)
plt.plot(np.random.rand(5))
plt.title("axes 4")

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 2)

np.random.seed(0)
axes[0, 0].plot(np.random.rand(5))
axes[0, 0].set_title("axes 1")
axes[0, 1].plot(np.random.rand(5))
axes[0, 1].set_title("axes 2")
axes[1, 0].plot(np.random.rand(5))
axes[1, 0].set_title("axes 3")
axes[1, 1].plot(np.random.rand(5))
axes[1, 1].set_title("axes 4")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Axis
# 여러가지 플롯을 하나의 Axes 객체에 표시할 때 y 값의 크기가 달라서 표시하기 힘든 경우가 있음. 이 때는 다음처럼 twinx 명령으로
# 복수의 y 축을 가진 플롯을 만들 수 있음. twinx 명령은 x축을 공유하는 새로운 Axes 객체를 만듬

# %%
fig, ax0 = plt.subplots()
ax1 = ax0.twinx()
ax0.set_title("2개의 y축 한 figure에서 사용하기")
ax0.plot([10, 5, 2, 9, 7], 'r-', label = "y0")
ax0.set_ylabel("y0")
ax0.grid(False)
ax1.plot([100, 200, 220, 180, 120], 'g:', label="y1")
ax1.set_ylabel("y1")
ax1.grid(False)
ax0.set_xlabel("공유되는 x축")
plt.show()

# %%
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

titanic = sns.load_dataset("titanic")
titanic

plt.title("타이타닉호 생존 여부")
plt.xlabel("인원 수")
color = ['red', 'green']
n = titanic.alive.value_counts()
print(n)
m = ["사망자", "생존자"]
plt.barh(m, n, color= color)
# Out:
# no     549
# yes    342
# Name: alive, dtype: int64
# <BarContainer object of 2 artists>

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

titanic = sns.load_dataset("titanic")
bar_chart = titanic["alive"].value_counts()
bar_chart.rename({'no':'사망자', 'yes':'생존자'}, inplace=True)
bar_chart
# Out:
# 사망자    549
# 생존자    342
# Name: alive, dtype: int64

# %%
alive = bar_chart.index
value = bar_chart.values
bar_colors = ["red", "green"]

plt.title("타이타닉호 생존여부")
plt.barh(alive, value,  color=bar_colors)
plt.xlabel('인원 수')
plt.show()

# %%
fig, ax = plt.subplots()

alive = bar_chart.index
value = bar_chart.values
bar_colors = ["red", "green"]

ax.set_title("타이타닉호 생존여부")
ax.barh(alive, value,  color=bar_colors)
ax.set_xlabel('인원 수')
plt.show()

# %% [markdown]
# ### 파이차트

# %%
labels = ['월세', '전세', '자가', '기타']
sizes = [15, 30, 45, 10]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
explode = (0, 0, 0.1, 0)
plt.title("Pie Chart")
plt.pie(sizes, explode = explode, labels = labels, colors= colors,
        autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal') # 원의 형태를 유지
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### 연습문제

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

titanic = sns.load_dataset("titanic")
bins = [0, 20, 30, 50, 70, 100]
labels = ["미성년자", "청년", "장년", "중년", "노년"]
explode = (0, 0, 0.1, 0, 0)
colors = ["yellowgreen", "gold", "lightskyblue", "lightcoral", "orange"]

titanic.head()
titanic.dropna(subset=["age"], inplace=True)
titanic.count()
age_cut = pd.cut(titanic["age"].values,bins,labels=labels)
age_cut.value_counts()
# Out:
# 미성년자    179
# 청년      230
# 장년      241
# 중년       59
# 노년        5
# dtype: int64

# %%
plt.title("age")
plt.pie(age_cut.value_counts(True), explode = explode, labels = labels, colors= colors,
        autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal') # 원의 형태를 유지
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## 히스토그램

# %% [markdown]
# hist 명령은 bins 인수로 데이터를 집계할 구간 정보를 받음. 반환 값으로 데이터 집계 결과를 반환

# %%
np.random.seed(0)
x = np.random.randn(1000)
plt.title("Histogram")
arrays, bins, patches = plt.hist(x, bins = 10)
plt.show()

# %%
arrays
# Out:
# array([  9.,  20.,  70., 146., 217., 239., 160.,  86.,  38.,  15.])

# %%
bins
# Out:
# array([-3.04614305, -2.46559324, -1.88504342, -1.3044936 , -0.72394379,
#        -0.14339397,  0.43715585,  1.01770566,  1.59825548,  2.1788053 ,
#         2.75935511])

# %% [markdown]
# ## 스캐터 플롯
# 2차원 데이터, 즉 두개의 실수 데이터 집합의 상관관계를 살펴보려면 scatter 명령으로 스캐터 플롯을 그림

# %%
np.random.seed(0)
X = np.random.normal(0, 1, 100)
Y = np.random.normal(0, 1, 100)
plt.title("Scatter Plot")
plt.scatter(X,Y)
plt.show()

# %%
N = 30
np.random.seed(0)
x = np.random.rand(N)
y1 = np.random.rand(N)
y2 = np.random.rand(N)
y3 = np.pi  * (15 * np.random.rand(N))**2
plt.title("Bubble Chart")
plt.scatter(x, y1, c = y2, s = y3)
plt.show()

# %% [markdown]
# ## imshow

# %% [markdown]
# 화상 데이터처럼 행과 열을 가진 행렬 형태의 2차원 데이터는 imshow 명령을 써서 2차원 자료의 크기를 색깔로 표시하는 것

# %%
from sklearn.datasets import load_digits

digits = load_digits()
X = digits.images[0]
X
# Out:
# array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#        [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#        [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#        [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#        [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#        [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#        [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#        [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]])

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

plt.title("mnist digits; 0")
plt.imshow(X, interpolation = 'nearest', cmap=plt.cm.bone_r)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.subplots_adjust(left=0.35, right= 0.65, bottom = 0.35, top = 0.65)
plt.show()

# %% [markdown]
# 데이터 수치를 색을 바꾸는 함수는 칼라맵이라함. 칼라맵은 cmap 인수로 지정
# 이는 plt.cm의 속성으로 포함되어 있음

# %%
dir(plt.cm)[:10]
# Out:
# ['Accent',
#  'Accent_r',
#  'Blues',
#  'Blues_r',
#  'BrBG',
#  'BrBG_r',
#  'BuGn',
#  'BuGn_r',
#  'BuPu',
#  'BuPu_r']

# %%
fig, axes = plt.subplots(1, 4, figsize = (12, 3),
                         subplot_kw={'xticks' : [], 'yticks' : []})
axes[0].set_title("plt.cm.Blues")
axes[0].imshow(X, interpolation = 'nearest', cmap=plt.cm.Blues)
axes[1].set_title("plt.cm.Blues_r")
axes[1].imshow(X, interpolation = 'nearest', cmap=plt.cm.Blues_r)
axes[2].set_title("plt.cm.BrBG")
axes[2].imshow(X, interpolation = 'nearest', cmap=plt.cm.BrBG)
axes[3].set_title("plt.cm.BrBG_r")
axes[3].imshow(X, interpolation = 'nearest', cmap=plt.cm.BrBG_r)
plt.show()

# %%
methods = [
    None, 'none', 'nearest', 'bilinear', 'bicubic', 'spline16',
    'spline36', 'hanning', 'hamming', 'hermite', 'kaiser', 'quadric',
    'catrom', 'gaussian', 'bessel', 'mitchell', 'sinc', 'lanczos'
]
fig, axes = plt.subplots(3, 6, figsize=(12, 6),
                         subplot_kw={'xticks': [], 'yticks': []})
for ax, interp_method in zip(axes.flat, methods):
    ax.imshow(X, cmap=plt.cm.bone_r, interpolation=interp_method)
    ax.set_title(interp_method)
plt.show()

# %% [markdown]
# ## 컨투어 플롯

# %%
def f(x, y):
    return (1 - x / 2 + x ** 5 + y ** 3) * np.exp(-x ** 2 - y **2)

n = 256
x = np.linspace(-3, 3, n)
y = np.linspace(-3, 3, n)
XX, YY = np.meshgrid(x, y)
zz = f(XX,YY)

plt.title("Contour plots")
plt.contourf(XX,YY, zz, alpha= 1, cmap='jet') #alpha 는 투명한 정도
plt.contour(XX, YY, zz, colors='black')
plt.show()

# %% [markdown]
# ## 3D 서비스 플롯
# 3차원 플롯은 등고선 플롯과 달리 Axes3D라는 3차원 전용 axes 생성하여 입체적으로 표시한다.
# plot_wireframe(), plot_surface() 명령을 사용

# %%
from mpl_toolkits.mplot3d import Axes3D
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)
XX, YY = np.meshgrid(X, Y)
RR = np.sqrt(XX**2 + YY**2)
zz = np.sin(RR)

fig = plt.figure()
ax = Axes3D(fig)
ax.set_title("3D Surface Plot")
ax.plot_surface(XX, YY, zz, rstride=1, cstride=1, cmap = 'hot')
plt.show()
# Out:
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_10152\1886078341.py:9: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %%
from mpl_toolkits.mplot3d import Axes3D
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)
XX, YY = np.meshgrid(X, Y)
RR = np.sqrt(XX**2 + YY**2)
ZZ = np.sin(RR)

fig = plt.figure()
ax = Axes3D(fig)
ax.set_title('3D surface Plot')
ax.plot_surface(XX, YY,ZZ, rstride = 1, cstride = 1, cmap = 'hot')
plt.show()
# Out:
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_10152\245633225.py:9: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %%
itanic = sns.load_dataset("titanic")
titanic.count()
titanic.dropna(subset=["age"], inplace=True)
titanic.count()
titanic["adult_female"] = (titanic["sex"] == "female") & (titanic["age"] >= 20)
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
titanic.to_csv('titanic_age.csv')
pd.read_csv('titanic_age.csv')
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 709         885         0       3  female  39.0      0      5  29.1250
# 710         886         0       2    male  27.0      0      0  13.0000
# 711         887         1       1  female  19.0      0      0  30.0000
# 712         889         1       1    male  26.0      0      0  30.0000
# 713         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone  \
# ...

# %% [markdown]
# pandas 연습문제

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
titanic.groupby('pclass').mean()
# Out:
#         survived        age     sibsp     parch       fare  adult_male  \
# pclass
# 1       0.655914  38.233441  0.451613  0.408602  87.961582    0.526882
# 2       0.479769  29.877630  0.427746  0.404624  21.471556    0.520231
# 3       0.239437  25.140620  0.585915  0.456338  13.229435    0.633803
#
#            alone  adult_female
# pclass
# 1       0.462366      0.381720
# 2       0.537572      0.335260
# 3       0.633803      0.160563

# %%
import pandas as pd
import seaborn as sns
import numpy as np

titanic = sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
a=titanic.groupby('pclass').sum()
titanic.groupby('pclass').sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10152\1802530105.py in <module>
#       1 a=titanic.groupby('pclass').sum()
# ----> 2 titanic['survived'].groupby('pclass').sum()
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    1920         # error: Argument "squeeze" to "SeriesGroupBy" has incompatible type
#    1921         # "Union[bool, NoDefault]"; expected "bool"
# -> 1922         return SeriesGroupBy(
#    1923             obj=self,
#    1924             keys=by,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     880             from pandas.core.groupby.grouper import get_grouper
# ...

# %%
b=titanic.groupby('pclass').size()
titanic.groupby('pclass').size()
# Out:
# pclass
# 1    216
# 2    184
# 3    491
# dtype: int64

# %%
a['survived']
# Out:
# pclass
# 1    136
# 2     87
# 3    119
# Name: survived, dtype: int64

# %%
a['survived'] / b
# Out:
# pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# dtype: float64

# %%
titanic[['pclass', 'survived']].groupby('pclass').mean()
# Out:
#         survived
# pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %% [markdown]
# ## 다른 방법!

# %%
groups = titanic.groupby(["pclass"])
groups.groups
# Out:
# {1: [1, 3, 6, 11, 23, 27, 30, 31, 34, 35, 52, 54, 55, 61, 62, 64, 83, 88, 92, 96, 97, 102, 110, 118, 124, 136, 137, 139, 151, 155, 166, 168, 170, 174, 177, 185, 187, 194, 195, 209, 215, 218, 224, 230, 245, 248, 252, 256, 257, 258, 262, 263, 268, 269, 270, 273, 275, 284, 290, 291, 295, 297, 298, 299, 305, 306, 307, 309, 310, 311, 318, 319, 325, 329, 331, 332, 334, 336, 337, 339, 341, 351, 356, 366, 369, 370, 373, 375, 377, 380, 383, 390, 393, 412, 430, 434, 435, 438, 445, 447, ...], 2: [9, 15, 17, 20, 21, 33, 41, 43, 53, 56, 58, 66, 70, 72, 78, 84, 98, 99, 117, 120, 122, 123, 133, 134, 135, 144, 145, 148, 149, 150, 161, 178, 181, 183, 190, 191, 193, 199, 211, 213, 217, 219, 221, 226, 228, 232, 234, 236, 237, 238, 239, 242, 247, 249, 259, 265, 272, 277, 288, 292, 303, 308, 312, 314, 316, 317, 322, 323, 327, 340, 342, 343, 344, 345, 346, 357, 361, 385, 387, 389, 397, 398, 399, 405, 407, 413, 416, 417, 418, 426, 427, 432, 437, 439, 440, 443, 446, 450, 458, 463, ...], 3: [0, 2, 4, 5, 7, 8
# ...

# %%
groups.mean()[["survived"]]
# Out:
#         survived
# pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
groups = titanic.groupby(["sex"])
groups.groups
# Out:
# {'female': [1, 2, 3, 8, 9, 10, 11, 14, 15, 18, 19, 22, 24, 25, 28, 31, 32, 38, 39, 40, 41, 43, 44, 47, 49, 52, 53, 56, 58, 61, 66, 68, 71, 79, 82, 84, 85, 88, 98, 100, 106, 109, 111, 113, 114, 119, 123, 128, 132, 133, 136, 140, 141, 142, 147, 151, 156, 161, 166, 167, 172, 177, 180, 184, 186, 190, 192, 194, 195, 198, 199, 205, 208, 211, 215, 216, 218, 229, 230, 233, 235, 237, 240, 241, 246, 247, 251, 254, 255, 256, 257, 258, 259, 264, 268, 269, 272, 274, 275, 276, ...], 'male': [0, 4, 5, 6, 7, 12, 13, 16, 17, 20, 21, 23, 26, 27, 29, 30, 33, 34, 35, 36, 37, 42, 45, 46, 48, 50, 51, 54, 55, 57, 59, 60, 62, 63, 64, 65, 67, 69, 70, 72, 73, 74, 75, 76, 77, 78, 80, 81, 83, 86, 87, 89, 90, 91, 92, 93, 94, 95, 96, 97, 99, 101, 102, 103, 104, 105, 107, 108, 110, 112, 115, 116, 117, 118, 120, 121, 122, 124, 125, 126, 127, 129, 130, 131, 134, 135, 137, 138, 139, 143, 144, 145, 146, 148, 149, 150, 152, 153, 154, 155, ...]}

# %%
groups.mean()[["survived"]]
# Out:
#         survived
# sex
# female  0.742038
# male    0.188908

# %% [markdown]
# ## Seaborn이란
# seabornㅇ은 Matplotlib을 기반으로 다양한 색상 테마와 통계용 차트 등의 기능을 추가한 시각화 패키지
# 기본적인 시각화 기능은 Matplotlib 패키지에 의존하며, 통계기능은 Statsmodels 패키지에 의존

# %% [markdown]
# ### 카운트 플롯
# countplot()을 사용하면 각 카테고리 값마다의 데이터가 얼마나 있는지 표시할 수 있음
# 카운트 플롯은 카테고리별 히스토그램이라 볼 수 있음
# API와 옵션은 바차트와 동일

# %% [markdown]
# ### 테마를 활용해서 스타일 적용하기
# set_theme()는 global 범위의 테마를 적용해서 그래프를 쉽게 꾸밀수 있음.
# style 과 palette 키워드 인수를 활용
# import seaborn as sns
# sns.set_theme(style="whitegrid")
# (참고) set_context()의 인수로 paper, notebook, talk, poster 중 하나를 넣으면 해당하는 설정을 세팅할 수 있음

# %% [markdown]
# 카운트 플롯 예제

# %%
df = sns.load_dataset("titanic")
sns.countplot(x=df["class"])
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %% [markdown]
# ### hue 키워드
# hue 키워드 인수를 활용하여 분류할 두번째 변수를 설정할 수 있음.

# %%
sns.countplot(data= df, x="class", hue="alive")
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %% [markdown]
# data 키워드 인수에 DataFrame을 전달하고 x 키워드 인수에 DataFrame 중 매칭하고 싶은 column의 name 값을 전달하고 있음.
# 뿐만 아니라 hue 키워드 인수에도 DataFrame의 column name을 전달하고 있음을 알 수 있음

# %%
sns.countplot(data=df, x="class", hue="alive")
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %% [markdown]
# 플롯을 수평하게도 작성할 수 있음. y 키워드 인수에 data로 넘긴 DataFrame의 column name 값을 전달하면 됨
# 아래 예제는 그래프를 수평하게 표현하여 카테고리 레이블을 나타내는 legend(범례) 공간을 확보

# %%
sns.countplot(data=df, y="deck", hue="alive")
# Out:
# <AxesSubplot:xlabel='count', ylabel='deck'>

# %% [markdown]
# ## tips 데이터셋
# 각 column마다의 의미는 다음과 같음
# 1. total_bill: 총지불금액
# 2. tip : 팁
# 3. sex : 성별
# 4. smoker : 흡연여부
# 5. day : 요일
# 6. time : 식사 시간대
# 7. size : 식사 인원

# %% [markdown]
# ## rugplot()
# 러그플롯은 데이터 위치를 x축 위에 작은 선분(rug)으로 나타내어 실제 데이터들의 위치를 보여준다.
# 커널 밀도(kernel density)는 커널이라는 함수를 겹치는 방법으로 히스토그램보다 부드러운 형태의 분포 곡선을 보여주는 방법

# %%
tips = sns.load_dataset("tips")
tips

sns.kdeplot(data=tips, x="total_bill")
sns.rugplot(data=tips, x="total_bill")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip")
sns.rugplot(data=tips, x="total_bill", y="tip")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip")
sns.rugplot(data=tips, x="total_bill", y="tip", height=.1) # height 키워드 인수로 크기를 조정함
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
diamonds = sns.load_dataset("diamonds")
sns.scatterplot(data=diamonds, x="carat", y="price", s=5)
sns.rugplot(data=diamonds, x="carat", y="price", lw=1, alpha=.005)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %% [markdown]
# ## 히스토그램

# %% [markdown]
# ### penguins dataset

# %%
penguins = sns.load_dataset("penguins")
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins.species.value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
penguins.species.unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
sns.histplot(data=penguins, x="flipper_length_mm")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(data=penguins, y="flipper_length_mm")
# Out:
# <AxesSubplot:xlabel='Count', ylabel='flipper_length_mm'>

# %% [markdown]
# ## histplot() bin 너비 지정하기
# binwidth 키워드 인수를 사용하면 bin의 너비를 지정할 수 있음

# %%
sns.histplot(data=penguins, x="flipper_length_mm", binwidth=3)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %% [markdown]
# ## histplot() bin 개수 지정하기
# bins 키워드 인수를 사용해서 bin의 개수를 지정할 수 있음

# %%
sns.histplot(data=penguins, x="flipper_length_mm", bins=30)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %% [markdown]
# ## histplot() kde를 동시에 표시하기
# kde는 kernel density의 약자로 커널이라는 함수를 겹치는 방법으로 히스토그램보다
# 부드러운 형태의 분포곡선을 보여줌.

# %%
sns.histplot(data=penguins, x="flipper_length_mm", kde=True)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %% [markdown]
# ## histplot() hue 키워드 이용
# hue 키워드 인수에 분류 기준이 될 column label을 전달해서 여러 개의 히스토그램을 합친 것과 같은 결과의 그래프를 얻을 수 있음

# %%
sns.histplot(data=penguins, x="flipper_length_mm", hue = "species")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %% [markdown]
# ### histplot() stack 이용
# layer가 겹쳐서 표현되면 이를 누적하듯 표현하는 방법이 있음.
# stack 값을 전달하면 됨

# %%
sns.histplot(data=penguins, x="flipper_length_mm", hue = "species", multiple="stack")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %% [markdown]
# ### histplot() step 표현
# element 키워드 인수에 'step' 값을 전달

# %%
sns.histplot(data=penguins, x="flipper_length_mm", hue = "species", element="step")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %% [markdown]
# ## histplot() - poly 사용

# %%
sns.histplot(data=penguins, x="flipper_length_mm", hue = "species", element="poly")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %% [markdown]
# x축과 y축 모두 column할당하면 heatmap 으로 나타남

# %%
sns.histplot(data=penguins, x="bill_depth_mm",y="body_mass_g", hue = "species")
# Out:
# <AxesSubplot:xlabel='bill_depth_mm', ylabel='body_mass_g'>

# %% [markdown]
# x축과 y축 모두 column을 할당할 때 그 중 하나의 값이 이산값이라면 아래처럼 가능

# %%
sns.histplot(data=penguins, x="bill_depth_mm", y = "species", hue="species", legend=False)
# Out:
# <AxesSubplot:xlabel='bill_depth_mm', ylabel='species'>

# %% [markdown]
# ## 히스토그램 - displot()
# displot() 도 마찬가지로 1차우너 혹은 2차원 데이터 분포를 히스토그램으로 보여줌
# 다만 rug와 kde에 대해 동시에 표현이 가능해서 표현범위가 더 넓고 이데 따라 많이 사용됨

# %%
sns.displot(data=penguins, x="flipper_length_mm")

# %% [markdown]
# ### kde 인수 활용하기

# %%
sns.displot(data=penguins, x="flipper_length_mm", kind="kde")

# %% [markdown]
# ### ecdf 표현하기
# kind 키워드 인수에 ecdf(empirical cumulative distrivution functions)로 누적분포그래프 표현

# %%
sns.displot(data=penguins, x="flipper_length_mm", kind="ecdf")

# %% [markdown]
# ### displot() 히스토그램과 kde 동시에 표현하기
# kde 키워드 인수 값을 True로 전달하여 히스토그램과 kde 동시에 표현하기
# 앞선 kind=kde와 비교해보기

# %%
sns.displot(data=penguins, x="flipper_length_mm", kde=True)

# %% [markdown]
# ### displot() x, y 모두 값 할당하기
# x, y 모두 할당하면 히트맵으로 표현가능

# %%
sns.displot(data=penguins, x="flipper_length_mm", y="bill_length_mm", hue="species")

# %% [markdown]
# ### displot() 2개 값을 kde로 표현하기
# x, y 모두 히스토그램을 kde로 표현가능. rug=True 키워드 인수를 전달해서 rug에 대한 표현도 가능

# %%
sns.displot(data=penguins, x="flipper_length_mm", y="bill_length_mm", kind="kde", rug=True)
